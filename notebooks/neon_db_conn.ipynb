# %%
import pandas as pd
import psycopg2
from datetime import datetime, timedelta
import os

# Neon Database Configuration
NEON_CONNECTION_STRING = 'postgresql://neondb_owner:npg_y3FsK7LWvIlP@ep-young-flower-afwkgbbl-pooler.c-2.us-west-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require'

TAGS_TO_MONITOR = [
    'OAK_EST_UP_LVL',
    'OAK_EST_DN_LEVEL'
]

try:
    print("Attempting connection...")
    conn = psycopg2.connect(NEON_CONNECTION_STRING, connect_timeout=10)
    print("✓ Connection successful!")
    
    cur = conn.cursor()
    cur.execute("SELECT version();")
    version = cur.fetchone()
    print(f"✓ PostgreSQL: {version[0]}")
    
    cur.close()
    conn.close()
except Exception as e:
    print(f"✗ Connection failed: {e}")
# Out:
# Attempting connection...
# ✓ Connection successful!
# ✓ PostgreSQL: PostgreSQL 17.5 (6bc9ef8) on aarch64-unknown-linux-gnu, compiled by gcc (Debian 12.2.0-14+deb12u1) 12.2.0, 64-bit
